# %%
import matplotlib.pyplot as plt
from datasets import train_loader, valid_loader
from datasets import visualize_batch

# %%
images,targets = next(iter(train_loader))

# %%
visualize_batch(images,targets)
